# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn
import spacy
import nltk
import re
import string
from bs4 import BeautifulSoup
from collections import Counter 
# nltk.download('words') # Use for English language corpus
# nltk.download('punkt') # Download for sentence and word tokenization

# %% [markdown]
# ### First, we will import the dataset of Medium articles
#
# ##### This data is available on Kaggle: [click here](https://www.kaggle.com/hsankesara/medium-articles)

# %%
articles = pd.read_csv('data/articles.csv')
articles.head(3)
# Out:
#              author claps  reading_time  \
# 0        Justin Lee  8.3K            11
# 1       Conor Dewey  1.4K             7
# 2  William Koehrsen  2.8K            11
#
#                                                 link  \
# 0  https://medium.com/swlh/chatbots-were-the-next...
# 1  https://towardsdatascience.com/python-for-data...
# 2  https://towardsdatascience.com/automated-featu...
#
#                                                title  \
# 0  Chatbots were the next big thing: what happene...
# 1  Python for Data Science: 8 Concepts You May Ha...
# 2  Automated Feature Engineering in Python – Towa...
#
#                                                 text
# 0  Oh, how the headlines blared:\nChatbots were T...
# 1  If you’ve ever found yourself looking up the s...
# 2  Machine learning is increasingly moving from h...

# %%
# Import the wordcloud library
from wordcloud import WordCloud
# Join the different processed titles together.
title_string = ','.join(list(articles.title.values))
# Create a WordCloud object
wordcloud = WordCloud(background_color="white", max_words=500, contour_width=3, contour_color='grey')
# Generate a word cloud
wordcloud.generate(title_string)
# Visualize the word cloud
plt.figure(figsize=(12,6))
plt.imshow(wordcloud, interpolation='bilinear')#.to_image()
plt.axis('off')
plt.show()

# %%
## For this dataset, we need to perform some basic data cleaning on some of the columns

# Format claps from string into integer
claps_number = []
for clap in articles.claps:
    if 'K' in str(clap):
        clap_num = clap[:-1]
        clap_num = float(clap_num) * 1000
        claps_number.append(int(clap_num))
    else:
        claps_number.append(clap)

# %%
articles['claps'] = claps_number # Convert the claps column into the formatted number
filtered_columns = ['author','claps','title','text'] # Select columns in dataframe
articles = articles[filtered_columns]
articles.head()
# Out:
#              author claps                                              title  \
# 0        Justin Lee  8300  Chatbots were the next big thing: what happene...
# 1       Conor Dewey  1400  Python for Data Science: 8 Concepts You May Ha...
# 2  William Koehrsen  2800  Automated Feature Engineering in Python – Towa...
# 3      Gant Laborde  1300  Machine Learning: how to go from Zero to Hero ...
# 4  Emmanuel Ameisen   935  Reinforcement Learning from scratch – Insight ...
#
#                                                 text
# 0  Oh, how the headlines blared:\nChatbots were T...
# 1  If you’ve ever found yourself looking up the s...
# 2  Machine learning is increasingly moving from h...
# 3  If your understanding of A.I. and Machine Lear...
# 4  Want to learn about applied Artificial Intelli...

# %%
## Preprocess text for analysis

def remove_punct(text):
    text = re.sub(r'[^\w\s]','',text)
    return text
    
def remove_unprintable_characters(text):
    # Will eliminate non-English text characters
    printable = set(string.printable)
    text = "".join(filter(lambda x: x in printable, text))
    return text

def remove_special_characters(text, remove_digits=False):
    pattern = r'[^a-zA-z0-9\s]' if not remove_digits else r'[^a-zA-z\s]'
    text = re.sub(pattern, '', text)
    return text

def lower_all_text(text):
    text = text.lower()
    return text

def remove_stop_words(text):
    stop_words = set(nltk.corpus.stopwords.words('english'))
    text = [ w for w in nltk.wordpunct_tokenize(text) if not w in stop_words ]
    text = str(" ".join(w for w in text))
    return text

def lemmatize_text(text):
    nlp = spacy.load('en_core_web_sm')
    text = nlp(text)
    text = ' '.join([word.lemma_ if word.lemma_ != '-PRON-' else word.text for word in text])
    return text

## Other options for preprocessing: Remove hyperlinks, remove breaks, lemmatize, stem, remove characters

# %%
def preprocess_text(text, 
                    remove_punctuation=True, 
                    printable_only=True,
                    remove_special=True,
                    lower_all=True, 
                    stop_words=True,
                    lemmatize=True,
                    no_digits=False):
    if remove_punctuation:
        text = remove_punct(text)
    if printable_only==True:
        text = remove_unprintable_characters(text)
    if remove_special:
        text = remove_special_characters(text, remove_digits=no_digits)
    if lower_all==True:
        text = lower_all_text(text)
    if stop_words==True:
        text = remove_stop_words(text)
    if lemmatize:
        text = lemmatize_text(text)
    return text

# %% [markdown]
# <b>NOTE:</b> Originally, I had created a function to eliminate English words using NLTK's words corpus. However, I noticed that it was removing a lot of proper nouns and terms that would be highly relevant to data science topics. So, instead, I applied the English filter below but kept all of the words in the preprocessed text for the future analysis. This is a good example of understanding the order of operations for text pre-processing.

# %%
## Apply this custom function to the text of the articles in our dataset

if 0==1: # Change this to a TRUE statement to run the above function in a customised way on the articles
    articles['preprocessed_text'] = [ preprocess_text(article) for article in articles.text ]

else:   # Or, you can just retrieve the dataset preprocessed with all the parameters initialised
    articles = pd.read_csv('data/preprocessed_articles.csv').iloc[:,1:]

# %%
## Now let's look at the dataset after these modifications (or to retrieve the DataFrame)
articles
# Out:
#                   author  claps  \
# 0             Justin Lee   8300
# 1            Conor Dewey   1400
# 2       William Koehrsen   2800
# 3           Gant Laborde   1300
# 4       Emmanuel Ameisen    935
# ..                   ...    ...
# 332       Daniel Simmons   3400
# 333  Eugenio Culurciello   2800
# 334           Devin Soni   5800
# 335      Carlos E. Perez   3900
# 336      Nityesh Agarwal   2400
#
#                                                  title  \
# 0    Chatbots were the next big thing: what happene...
# 1    Python for Data Science: 8 Concepts You May Ha...
# 2    Automated Feature Engineering in Python – Towa...
# 3    Machine Learning: how to go from Zero to Hero ...
# 4    Reinforcement Learning from scratch – Insight ...
# ..                                                 ...
# 332  You can build a neural network in JavaScript e...
# 333  Artificial Intelligence, AI in 2018 and beyond...
# 334  Spiking Neural Networks, the Next Generation o...
# 335  Surprise! Neurons are Now More Complex than We...
# 336  “WTH does a neural network even learn??” — a n...
#
#                                                   text  \
# 0    Oh, how the headlines blared:\nChatbots were T...
# 1    If you’ve ever found yourself looking up the s...
# 2    Machine learning is increasingly moving from h...
# 3    If your understanding of A.I. and Machine Lear...
# 4    Want to learn about applied Artificial Intelli...
# ..                                                 ...
# 332  Click here to share this article on LinkedIn »...
# 333  These are my opinions on where deep neural net...
# 334  Everyone who has been remotely tuned in to rec...
# 335  One of the biggest misconceptions around is th...
# 336  I believe, we all have that psychologist/philo...
#
#                                      preprocessed_text
# 0    oh headline blare chatbot next big thing hope ...
# 1    you have ever find look question concept synta...
# 2    machine learn increasingly move handdesigne mo...
# 3    understanding ai machine learn big question ma...
# 4    want learn apply artificial intelligence lead ...
# ..                                                 ...
# 332  click share article linkedin skip part want ge...
# 333  opinion deep neural network machine learning h...
# 334  everyone remotely tune recent progress machine...
# 335  one big misconception around idea deep learn d...
# 336  believe psychologistphilosopher brain like pon...
#
# [337 rows x 5 columns]

# %%
## To filter our dataset to articles in English, we will identify those articles with predominantly English words.
## We will do this using nltk's corpus of Enlgish words.

def english_only(text):
    english_corpus = set(nltk.corpus.words.words())
    text = [ w for w in nltk.wordpunct_tokenize(text) if w in english_corpus ]
    return text

def english_filter(text):
    word_count = len(nltk.wordpunct_tokenize(text))
    english_word_count = len(english_only(text))
    ratio = round(english_word_count / word_count,2)
    return ratio

# %%
## Now let's take a look at the code

if 0 == 1:
    # Set the above formula to TRUE to run the function for yourself
    articles['english_article'] = [ english_filter(article) for article in articles.text ]
    articles.head()

else:
    articles = pd.read_csv('data/preprocessed_articles_english_only.csv').iloc[:,1:]

# %%
articles.head()
# Out:
#              author  claps                                              title  \
# 0        Justin Lee   8300  Chatbots were the next big thing: what happene...
# 1       Conor Dewey   1400  Python for Data Science: 8 Concepts You May Ha...
# 2  William Koehrsen   2800  Automated Feature Engineering in Python – Towa...
# 3      Gant Laborde   1300  Machine Learning: how to go from Zero to Hero ...
# 4  Emmanuel Ameisen    935  Reinforcement Learning from scratch – Insight ...
#
#                                                 text  \
# 0  Oh, how the headlines blared:\nChatbots were T...
# 1  If you’ve ever found yourself looking up the s...
# 2  Machine learning is increasingly moving from h...
# 3  If your understanding of A.I. and Machine Lear...
# 4  Want to learn about applied Artificial Intelli...
#
#                                    preprocessed_text  english_article
# 0  oh headline blare chatbot next big thing hope ...             0.67
# 1  you have ever find look question concept synta...             0.73
# 2  machine learn increasingly move handdesigne mo...             0.71
# 3  understanding ai machine learn big question ma...             0.71
# 4  want learn apply artificial intelligence lead ...             0.71

# %%
## Then we can check articles by their 'English ratio' to sense check the results, this may depend on the dataset
threshold = 0.40

## After some simple examination of the Medium articles it looks like a good threshold is 40%.
## This will account for all of the proper nouns, typos, and uncommon words used in the field of data science.
articles['is_english'] = articles.english_article > threshold
articles[articles.is_english == False]
# Out:
#                               author  claps  \
# 23                         Xu Wenhao      1
# 53               I'Boss Potiwarakorn    128
# 79                          Mybridge  10100
# 167  Erick Muzart Fonseca dos Santos     16
# 234                  Diana Filippova      1
# 288                Maryna Hlaiboroda      5
# 307                   Nieves Ábalos     18
#
#                                                  title  \
# 23                            建议的程序员学习LDA算法的步骤 – 蒸汽与魔法
# 53   Machine Learning เรียนอะไร, รู้ไปทําไม – O v e...
# 79   30 Amazing Machine Learning Projects for the P...
# 167  O Grupo de Estudo em Deep Learning de Brasíli...
# 234  De la coopération entre les hommes et les mac...
# 288   ИИ-психопат и ИИ-обманщик – Hey Machine Learning
# 307  Semántica desde información desestructurada ...
#
#                                                   text  \
# 23   这一阵为了工作上的关系,花了点时间学习了一下LDA算法,说实话,对于我这个学CS而非学数学的...
# 53   Machine Learning จริงๆแล้วมันคืออะไรกันแน่? คร...
# 79   For the past year, we’ve compared nearly 8,800...
# 167  O Grupo de Estudo em Deep Learning de Brasíli...
# 234  Originally published at www.cuberevue.com on N...
# 288  Команда исследователей из Массачусетского тех...
# 307  Detectar patrones es un núcleo importante en ...
#
#                                      preprocessed_text  english_article  \
# 23   ldacs bleidirichletaimachine learningprmlbleit...             0.10
# 53   machine learn machine learn machine learn mach...             0.18
# 79   past year we have compare nearly 8800 open sou...             0.40
# 167  grupo de estudo em deep learning de brasilia e...             0.39
# 234  originally publish wwwcuberevuecom november 6 ...             0.40
# 288  mit norman reddit norman mit norman mit norman...             0.04
# 307  detectar patrones es un nucleo importante en e...             0.36
#
#      is_english
# 23        False
# 53        False
# 79        False
# 167       False
# 234       False
# 288       False
# 307       False

# %%
## So we reset the dataframe, excluding the non-English articles
articles = articles[articles.is_english == True].reset_index(drop=True)
print('There are {} articles in the new dataframe.'.format(len(articles)))
# Out:
# There are 330 articles in the new dataframe.

# %% [markdown]
# ## Using Machine Learning to analyse the text, including predicting 'claps' from text and titles of articles and visualising the topics discussed.
#
# #### Approach 1: scikit-learn prediction models
#
# - DummyRegressor (to baseline against random chance)
# - CountVectorizer
# - TfidfVectorizer

# %%
## First, let's initialise the training and test data

from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

X = articles.preprocessed_text
y = articles.claps

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=47)

# %%
## How does this prediction do against random chance?
## To analyse this, we use sklearn's DummyRegressor on the data

from sklearn.dummy import DummyRegressor

dummy_clf = DummyRegressor()
dummy_clf.fit(X_train, y_train)
dummy_pred = dummy_clf.predict(X_test)

# Evaluate the squared MSE
np.sqrt(mean_squared_error(y_test, dummy_pred))
# Out:
# 11916.355916827633

# %%
## CountVectorizer using RandomForestRegressor

from sklearn.feature_extraction.text import CountVectorizer

vect = CountVectorizer() # Initiative variable 'stop_words' if not done during preprocessing

count_train = vect.fit_transform(X_train)

X_train_ctm = pd.DataFrame(count_train.toarray(),columns=vect.get_feature_names())

# Prepare testing data
count_test = vect.transform(X_test)

# %%
from sklearn.ensemble import RandomForestRegressor

count_RFR = RandomForestRegressor()

# Fit the model using the training array and training labels
count_RFR.fit(count_train, y_train)

# Run model on the testing data
count_y_pred = count_RFR.predict(count_test)

# Evaluate using squared mean squared error
np.sqrt(mean_squared_error(y_test, count_y_pred))
# Out:
# 10640.16092700755

# %%
## TfidfVectorizer, also using RandomForestRegressor

from sklearn.feature_extraction.text import TfidfVectorizer

tfidf = TfidfVectorizer()

tfidf_train = tfidf.fit_transform(X_train)

tfidf_test = tfidf.transform(X_test)

# %%
tfidf_RFR = RandomForestRegressor()

# Fit the model using the training array and training labels
tfidf_RFR.fit(tfidf_train, y_train)

# Run model on the testing data
tfidf_y_pred = tfidf_RFR.predict(tfidf_test)

# Evaluate using squared mean squared error
np.sqrt(mean_squared_error(y_test, tfidf_y_pred))
# Out:
# 10515.177886948355

# %%
y_pred = tfidf_y_pred # Sub out this value for any of the tests above to see the results

results = pd.DataFrame({'text':X_test,
                        'test':y_test,
                       'predicted':y_pred,
                       'difference':y_pred - y_test})

results.difference.hist()
plt.show()

# %% [markdown]
# #### Approach 2: word2vec for prediction

# %% [markdown]
# #### Approach 3: Topic Modelling
#
# ##### First, with Latent Dirichlet Allocation (LDA)

# %%
from sklearn.decomposition import LatentDirichletAllocation as LDA

# Initialise a Count Vectorizer for the entire article text corpus

text_to_topics = articles.text

LDA_vect = CountVectorizer(stop_words='english') 

LDA_count_data = LDA_vect.fit_transform(text_to_topics)

# Create and fit the LDA model
number_topics = 5
lda = LDA(n_components=number_topics, n_jobs=-1)
lda.fit(LDA_count_data)
# Out:
# LatentDirichletAllocation(batch_size=128, doc_topic_prior=None,
#                           evaluate_every=-1, learning_decay=0.7,
#                           learning_method='batch', learning_offset=10.0,
#                           max_doc_update_iter=100, max_iter=10,
#                           mean_change_tol=0.001, n_components=5, n_jobs=-1,
#                           perp_tol=0.1, random_state=None,
#                           topic_word_prior=None, total_samples=1000000.0,
#                           verbose=0)

# %%
# Helper function to visualise the topics and top words
def print_topics(model, count_vectorizer, n_top_words):
    words = count_vectorizer.get_feature_names()
    for topic_idx, topic in enumerate(model.components_):
        print("\nTopic {}:".format(str(topic_idx + 1)))
        print(" ".join([words[i]
                        for i in topic.argsort()[:-n_top_words - 1:-1]]))
        
def topic_clouds(model, count_vectorizer, n_top_words):
    words = count_vectorizer.get_feature_names()
    for topic_idx, topic in enumerate(model.components_):
        plt.subplots(1,1, sharex=True, figsize=(8,8))
        
        wordcloud = WordCloud(background_color="white", max_words=500, contour_width=3, contour_color='grey')
        topic_wordlist = " ".join([words[i] for i in topic.argsort()[:-n_top_words - 1:-1]])
        
        #topic_most_common = most_common_words(topic_wordlist)[:n_top_words]
        wordcloud.generate(topic_wordlist)
        plt.imshow(wordcloud, interpolation='bilinear')
        plt.title('Topic {}'.format(str(topic_idx + 1)), loc='left', fontsize=16)
        plt.axis('off')

# Tweak the number of words for display
print_number_words = 15

# Print out the top
print_topics(lda, LDA_vect, print_number_words)
# Out:
# Topic 1:
# network data neural model learning training image use function layer using input output like time
#
# Topic 2:
# learning data like deep network neural machine time use just way training computer using image
#
# Topic 3:
# people like ai time new just data work make intelligence ve human game use world
#
# Topic 4:
# learning machine data course ai science python reviews average hours algorithms companies available free rating
#
# Topic 5:
# human ai humans intelligence like just data way machines artificial need time world systems new

# %%
# Visualise the words in each topic as a word cloud for future labelling
cloud_number_words = 50

topic_clouds(lda, LDA_vect, cloud_number_words)

# %%
## Visualise with pyLDAvis

# %% [markdown]
# ##### Next, Entity Recognition

# %%
from spacy import displacy

nlp = spacy.load("en_core_web_sm")
doc = nlp("Apple is looking at buying U.K. startup for $1 billion")

#for ent in doc.ents:
#    print(ent.text, ent.start_char, ent.end_char, ent.label_)
    
displacy.render(doc, style="ent")

# %% [markdown]
# #### Approach 4: BERT for prediction

# %% [markdown]
# #### BONUS: Building a 'Clap Predictor' for article titles

# %%
X = articles.title
y = articles.claps

#X_train, X_test, y_train, y_test = train_test_split(X,y)

#pipeline = 

vect = CountVectorizer(stop_words='english')

count_train = vect.fit_transform(X)

model = RandomForestRegressor()

model.fit(count_train, y)

title_input = input('What is your title? ')

title_input_transformed = vect.transform(nltk.wordpunct_tokenize(title_input))
#print(title_input_transformed)
#model.predict(title_input_transformed)
print('You should receive {:.0f} claps for that title!'.format(model.predict(title_input_transformed).mean()))
# Out:
# What is your title? hello, this is about NLP and data science
# You should receive 98 claps for that title!

# %%
print(title_input_transformed)
# Out:
#   (5, 476)	1
#   (7, 177)	1
#   (8, 585)	1

# %% [markdown]
# #### Steps in the analysis
#
# 1. Import the dataset
# 2. Clean it, keeping only English articles and words
# 3. Create a pipeline to remove stop words, count, lemmatize
# 4. Apply some NER from either spaCy or nltk to get topics
# 5. Create a pipeline to fit a corpus of  articles
#
#     - Clean the data, removing stop words
#     - Applying train_test_split
#     - Fitting the model on training data
#     - predicting on test data
#     - outputting a MSE accuracy for regression
#     - build n_gram for multi-word phrases
#
#
# 6. Pipeline for predicting on a specific article
# 7. Title predictor tool

# %% [markdown]
# #### Analysis to perform
#
# - some basic exploratory analysis and charting
#     - use Bokeh for this? Would be good package to get comfortable with
# - Topic modeling with LDA
#     - use pyLDAvis for cool topic explorer
# - word2vec with gensim
# - keras for prediction

# %% [markdown]
# #### Credit and Acknowledgments
#
#  Ryan McCormack
#
#  [A practitioner's guide to Natural Language Processing Part 1 - DJ Sarkar](https://towardsdatascience.com/a-practitioners-guide-to-natural-language-processing-part-i-processing-understanding-text-9f4abfd13e72)
#
#  [Word Cloud code](https://towardsdatascience.com/end-to-end-topic-modeling-in-python-latent-dirichlet-allocation-lda-35ce4ed6b3e0)
