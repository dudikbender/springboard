# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
import statsmodels.api as sm
from statsmodels.graphics.mosaicplot import mosaic
from scipy.stats import chisquare

# %matplotlib inline

# %%
matplotlib.style.use('ggplot')

# %%
df = pd.read_csv('data/StartingGrantData.csv')[:-1]

field_names = {'1':'Life Sciences',
              '2': 'Social Sciences & Humanities',
              '3': 'Physical Sciences & Engineering',
              '4': 'Other'}

vr_values = {'0':'No',
            '1': 'Yes'}

df['Field'] = df['Field'].map(field_names)
df['VR'] = df['VR'].astype('int')

# %%
df.dtypes
# Out:
# ID                   object
# Field                object
# First5Years          object
# AppliedforGrants     object
# VR                   object
# SSMF                 object
# Ragnar               object
# ERC                  object
# SwedishFoundation    object
# Formas                int64
# Forte                 int64
# Wallenberg            int64
# GotaGrant            object
# SufficientVR         object
# SufficientSMSF       object
# SufficientRagnar     object
# SufficientERC        object
# SufficientSF         object
# dtype: object

# %%
df[['Field','VR']]
# Out:
#                             Field VR
# 0                   Life Sciences  0
# 1                   Life Sciences  1
# 2                   Life Sciences  1
# 3                   Life Sciences  0
# 4    Social Sciences & Humanities  0
# ..                            ... ..
# 410                 Life Sciences  1
# 411                 Life Sciences  1
# 412                 Life Sciences  1
# 413                 Life Sciences  1
# 414                           NaN
#
# [415 rows x 2 columns]

# %%
#fig, ax = plt.figure()
mosaic(df, ['Field','VR'])
plt.show()

# %%
tab = pd.crosstab(df2['VR Starting Grant'], columns=['Field'])
data = df[['VR', 'Field']]
table = sm.stats.Table.from_data(data)
chart_data = table.resid_pearson
sns.heatmap(chart_data, cmap=properties, annot=True)

# %%
df_table = table.table_orig.melt()
chart_Data = chart_data.melt()
chart_Data = chart_Data.reset_index()
chart_Data['value'] = [round(x, 2) for x in chart_Data['value']]

index_vals = []
for i in chart_Data['index']:
    if (i%2==0) | (i==0):
        i='No'
    else:
        i='Yes'
    index_vals.append(i)

# %%
chart_Data['index'] = index_vals
chart_Data
# Out:
#   index                            Field  value
# 0    No                    Life Sciences  -0.20
# 1   Yes                    Life Sciences   0.14
# 2    No                            Other  -0.26
# 3   Yes                            Other   0.18
# 4    No  Physical Sciences & Engineering  -1.60
# 5   Yes  Physical Sciences & Engineering   1.11
# 6    No     Social Sciences & Humanities   2.25
# 7   Yes     Social Sciences & Humanities  -1.56

# %%
field_vr = df[['Field','VR']]

field_vr['VR_no'] = [x=1 if ]
# Out:
#                                Field  VR
# 0                      Life Sciences   0
# 1                      Life Sciences   1
# 2                      Life Sciences   1
# 3                      Life Sciences   0
# 4       Social Sciences & Humanities   0
# ..                               ...  ..
# 409  Physical Sciences & Engineering   0
# 410                    Life Sciences   1
# 411                    Life Sciences   1
# 412                    Life Sciences   1
# 413                    Life Sciences   1
#
# [414 rows x 2 columns]

# %%
for i in field_vr['VR']

# %%
plt.figure(figsize=(10,10))

#color = lambda x: {'color':'blue' if df.]

_ = mosaic(chart_Data, index=['Field','value'])
plt.show()
